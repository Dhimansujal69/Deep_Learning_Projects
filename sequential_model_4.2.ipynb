# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

# %%
print("X Train Shape: ",x_train.shape)
print("X Test Shape: ",x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28, 1)
# X Test Shape:  (10000, 28, 28, 1)

# %%
model = keras.Sequential([

    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu',
        padding="same"
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),


    keras.layers.Conv2D(
        64,
        (3,3),
        activation='relu',
        padding="same"
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),


    keras.layers.Flatten(),

    keras.layers.Dense(
        64,
        activation = 'relu'
    ),
    keras.layers.Dense(
        10,
        activation = 'softmax'
    )
    
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9520 - loss: 0.1558 - val_accuracy: 0.9862 - val_loss: 0.0522
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9849 - loss: 0.0485 - val_accuracy: 0.9855 - val_loss: 0.0466
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9892 - loss: 0.0336 - val_accuracy: 0.9907 - val_loss: 0.0346
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9916 - loss: 0.0261 - val_accuracy: 0.9900 - val_loss: 0.0377
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9937 - loss: 0.0194 - val_accuracy: 0.9913 - val_loss: 0.0310
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9952 - loss: 0.0149 - val_accuracy: 0.9903 - val_loss: 0.0410
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9902 - val_loss: 0.0407
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9968 - loss: 0.0093 - val_accuracy: 0.9907 - val_loss: 0.0405
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9974 - loss: 0.0077 - val_accuracy: 0.9912 - val_loss: 0.0444
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 0.9898 - val_loss: 0.0493
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9912 - val_loss: 0.0467
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9986 - loss: 0.0043 - val_accuracy: 0.9920 - val_loss: 0.0459
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9907 - val_loss: 0.0498
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9907 - val_loss: 0.0461
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9989 - loss: 0.0032 - val_accuracy: 0.9930 - val_loss: 0.0438
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9917 - val_loss: 0.0554
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9918 - val_loss: 0.0577
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9984 - loss: 0.0043 - val_accuracy: 0.9897 - val_loss: 0.0693
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9927 - val_loss: 0.0515
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9890 - val_loss: 0.0822

# %%
test_loss, test_accuracy = model.evaluate (x_test,y_test)
print("Test Accuracy: ",test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9897 - loss: 0.0542
# Test Accuracy:  0.9897000193595886

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 3136)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         200,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 660,704 (2.52 MB)
#  Trainable params: 220,234 (860.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 440,470 (1.68 MB)

# %%
predictions = model.predict(x_train)

print("Predictions",predictions[:5])
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step
# Predictions [[9.0065555e-37 1.8030518e-24 1.0262717e-30 1.3393215e-09 5.6332662e-26
#   1.0000000e+00 2.5959859e-26 5.9331172e-27 4.8143052e-20 2.6580396e-15]
#  [1.0000000e+00 2.0316566e-29 3.1596063e-16 3.7751818e-24 1.9877028e-26
#   1.1982799e-19 6.7184959e-17 1.3014899e-19 2.8076363e-19 8.2495872e-18]
#  [1.3619683e-27 1.3195157e-07 1.9474300e-17 6.5773347e-21 9.9999988e-01
#   1.4264017e-17 4.7328363e-20 3.7691691e-15 1.6495912e-13 3.6322549e-12]
#  [3.0492386e-21 1.0000000e+00 1.2795551e-17 2.6359054e-23 1.5113892e-14
#   4.8763848e-15 4.4270661e-20 3.5941786e-16 7.2711056e-14 2.6355386e-19]
#  [7.0884713e-22 1.7773005e-16 5.7948183e-18 4.7263526e-12 2.0186623e-14
#   5.7164377e-14 4.5220104e-23 2.9350047e-09 3.1871692e-09 1.0000000e+00]]

# %%
predicted_labels = np.argmax(predictions, axis=1)

print("Predicted: ",predicted_labels[:5])
print("Actual: ",y_test[:5])
# Out:
# Predicted:  [5 0 4 1 9]
# Actual:  [7 2 1 0 4]

# %%
print("Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Training Accuracy: ", max(history.history["accuracy"]))
print("Testing Accuracy: ",test_accuracy)
# Out:
# Validation Accuracy:  0.9929999709129333
# Training Accuracy:  0.9992777705192566
# Testing Accuracy:  0.9897000193595886

# %%
print("Best Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Best Validation Loss: ", max(history.history["val_loss"]))
# Out:
# Best Validation Accuracy:  0.9929999709129333
# Best Validation Loss:  0.0822390615940094
