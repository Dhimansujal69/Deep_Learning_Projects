# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np

from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train),(x_test,y_test) = mnist.load_data()

# %%
#Normalization

x_train = x_train/255.0
x_test = x_test/255.0

# %%
print("X Train Shape: ",x_train.shape)
print("X Test Shape: ",x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28)
# X Test Shape:  (10000, 28, 28)

# %%
x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

# %%
print("X Train Shape: ",x_train.shape)
print("X Test Shape: ",x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28, 1)
# X Test Shape:  (10000, 28, 28, 1)

# %%
model = keras.Sequential([

    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu'
    ),
    
    keras.layers.MaxPooling2D(
        (2,2)
    ),

    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu'
    ),

    keras.layers.MaxPooling2D(
        (2,2)
    ),

    keras.layers.Flatten(),

    keras.layers.Dense(64, activation='relu'),

    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9487 - loss: 0.1682 - val_accuracy: 0.9842 - val_loss: 0.0494
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9842 - loss: 0.0513 - val_accuracy: 0.9872 - val_loss: 0.0431
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9883 - loss: 0.0358 - val_accuracy: 0.9880 - val_loss: 0.0420
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9913 - loss: 0.0271 - val_accuracy: 0.9897 - val_loss: 0.0361
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9933 - loss: 0.0215 - val_accuracy: 0.9882 - val_loss: 0.0447
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9941 - loss: 0.0177 - val_accuracy: 0.9922 - val_loss: 0.0290
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9956 - loss: 0.0137 - val_accuracy: 0.9907 - val_loss: 0.0376
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9963 - loss: 0.0111 - val_accuracy: 0.9890 - val_loss: 0.0469
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9927 - val_loss: 0.0384
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 0.9918 - val_loss: 0.0354
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9910 - val_loss: 0.0456
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9977 - loss: 0.0070 - val_accuracy: 0.9895 - val_loss: 0.0485
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9917 - val_loss: 0.0453
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9925 - val_loss: 0.0474
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.9893 - val_loss: 0.0596
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9918 - val_loss: 0.0445
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9890 - val_loss: 0.0569
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9913 - val_loss: 0.0472
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9922 - val_loss: 0.0482
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9920 - val_loss: 0.0653

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0480

# %%
print("Test Accurcay: ",test_accuracy)
# Out:
# Test Accurcay:  0.9912999868392944

# %%
predictions = model.predict(x_test)
print("Predictions: ", predictions[:5])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Predictions:  [[2.8718183e-18 1.5753812e-17 1.1349416e-19 1.8335292e-16 1.9620877e-27
#   3.1888359e-24 2.0217030e-25 1.0000000e+00 1.5779503e-16 1.9091170e-15]
#  [2.2205944e-12 9.2272130e-14 1.0000000e+00 3.7866826e-21 2.0028266e-18
#   1.6875713e-27 3.9650712e-18 4.6905654e-19 2.3325714e-12 2.7410088e-18]
#  [1.3815185e-11 1.0000000e+00 5.7304384e-16 1.5330949e-22 9.3796791e-13
#   4.1146167e-14 3.5320440e-12 2.4632667e-13 6.3660183e-13 3.8223842e-14]
#  [1.0000000e+00 2.9515194e-25 3.8610409e-23 1.6416203e-19 7.1382792e-18
#   2.1727025e-20 1.8699344e-09 1.3005965e-19 1.2729650e-14 6.1248852e-13]
#  [2.1041544e-19 1.3535213e-19 3.7961184e-18 1.4130476e-23 1.0000000e+00
#   1.8565788e-17 7.0230133e-22 5.6616558e-20 3.2005326e-14 2.1795381e-09]]

# %%
predicted_labels = np.argmax(
    predictions, axis=1)

print("Predicted: ",predicted_labels[:5])
print("Actual:    ",y_test[:5])
# Out:
# Predicted:  [7 2 1 0 4]
# Actual:     [7 2 1 0 4]

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 11, 11, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 5, 5, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 800)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 184,448 (720.50 KB)
#  Trainable params: 61,482 (240.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 122,966 (480.34 KB)
