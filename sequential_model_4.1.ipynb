# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.datasets import mnist
import numpy as np

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
print("X Train Shape: ",x_train.shape)
print("X Test Shape: ",x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28)
# X Test Shape:  (10000, 28, 28)

# %%
x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

# %%
print("X Train Shape: ", x_train.shape)
print("X Test Shape: ", x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28, 1)
# X Test Shape:  (10000, 28, 28, 1)

# %%
model = keras.Sequential([

    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu'
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),


    keras.layers.Conv2D(
        64,
        (3,3),
        activation = 'relu'
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),

    
    keras.layers.Flatten(),

    keras.layers.Dense(64, activation='relu'),

    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9536 - loss: 0.1528 - val_accuracy: 0.9867 - val_loss: 0.0504
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9841 - loss: 0.0519 - val_accuracy: 0.9840 - val_loss: 0.0545
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9886 - loss: 0.0360 - val_accuracy: 0.9885 - val_loss: 0.0398
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9918 - loss: 0.0262 - val_accuracy: 0.9893 - val_loss: 0.0384
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9935 - loss: 0.0194 - val_accuracy: 0.9872 - val_loss: 0.0436
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9873 - val_loss: 0.0410
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.9912 - val_loss: 0.0414
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9966 - loss: 0.0103 - val_accuracy: 0.9885 - val_loss: 0.0439
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9922 - val_loss: 0.0402
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9976 - loss: 0.0064 - val_accuracy: 0.9907 - val_loss: 0.0516
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9975 - loss: 0.0076 - val_accuracy: 0.9922 - val_loss: 0.0387
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9912 - val_loss: 0.0437
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9983 - loss: 0.0046 - val_accuracy: 0.9910 - val_loss: 0.0617
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9978 - loss: 0.0067 - val_accuracy: 0.9922 - val_loss: 0.0441
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9983 - loss: 0.0048 - val_accuracy: 0.9888 - val_loss: 0.0647
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9917 - val_loss: 0.0539
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9986 - loss: 0.0040 - val_accuracy: 0.9928 - val_loss: 0.0536
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9913 - val_loss: 0.0558
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9915 - val_loss: 0.0507
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9915 - val_loss: 0.0510

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9915 - loss: 0.0391

# %%
print("Test Accuracy: ",test_accuracy)
# Out:
# Test Accuracy:  0.9915000200271606

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
print("Predictions: ",predictions)
# Out:
# Predictions:  [[3.1171908e-23 1.3193922e-17 2.6906603e-18 ... 1.0000000e+00
#   2.0380454e-21 2.2906807e-13]
#  [2.4005875e-15 1.2784946e-12 1.0000000e+00 ... 4.5536389e-22
#   7.1147641e-18 1.1680917e-25]
#  [2.7162364e-10 1.0000000e+00 1.4336724e-11 ... 6.2305627e-10
#   2.2923875e-11 3.3590819e-12]
#  ...
#  [2.1990579e-22 7.4427912e-19 3.3228338e-21 ... 5.3833609e-20
#   8.2084417e-16 4.2532515e-18]
#  [2.4724841e-16 8.0997472e-27 5.9804955e-27 ... 2.5925534e-25
#   3.8451503e-16 1.0657620e-23]
#  [4.1486619e-13 2.5744508e-16 2.1936586e-14 ... 4.4037268e-25
#   5.8334976e-11 9.4131508e-22]]

# %%
predicted_labels = np.argmax(predictions, axis=1)

print("Predicted: ",predicted_labels[:5])
print("Actual: ",y_test[:5])
# Out:
# Predicted:  [7 2 1 0 4]
# Actual:  [7 2 1 0 4]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │         102,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 365,792 (1.40 MB)
#  Trainable params: 121,930 (476.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 243,862 (952.59 KB)

# %%
print("Best Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Best Validation Loss: ", max(history.history["val_loss"]))
# Out:
# Best Validation Accuracy:  0.9928333163261414
# Best Validation Loss:  0.06472913175821304

# %%
print("Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Training Accuracy: ", max(history.history["accuracy"]))
print("Testing Accuracy: ",test_accuracy)
# Out:
# Validation Accuracy:  0.9928333163261414
# Training Accuracy:  0.998962938785553
# Testing Accuracy:  0.9915000200271606

# %%
print(x_train.shape)
print(x_test.shape)

print(x_train.min(), x_train.max())
print(x_test.min(), x_test.max())
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# 0.0 1.0
# 0.0 1.0
