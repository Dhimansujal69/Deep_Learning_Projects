# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rishav\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rishav\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rishav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rishav\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\rishav\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\rishav\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\rishav\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rishav\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rishav\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rishav\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.21.0

# %%
tensors =tf.constant([1,2,3,4,5])
print(tensors)
# Out:
# tf.Tensor([1 2 3 4 5], shape=(5,), dtype=int32)

# %%
#1D
scalar  = tf.constant(10)
print(scalar)
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
#2D
vector = tf.constant([1,2,3,4])
print(vector)
# Out:
# tf.Tensor([1 2 3 4], shape=(4,), dtype=int32)

# %%
#3D
matrix = tf.constant([
    [1,2],
    [3,4]
])

print(matrix)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
tensor_3d = tf.constant([[
    [1,2],
    [3,4]],

    [[5,6],
     [7,8]]
                        ])
print(tensor_3d)
# Out:
# tf.Tensor(
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]], shape=(2, 2, 2), dtype=int32)

# %%
tensor = tf.constant([[1,2],[3,4]])

print(tensor.shape)
# Out:
# (2, 2)

# %%
print(tensor.dtype)
# Out:
# <dtype: 'int32'>

# %%
print(tensor.ndim)
# Out:
# 2

# %%
a = tf.constant([1,2,3])

b = tf.constant([4,5,6])

# %%
print(a+b)
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)

# %%
print(a*b)
# Out:
# tf.Tensor([ 4 10 18], shape=(3,), dtype=int32)

# %%
c = tf.constant([[1,2],
                 [3,4]])
d = tf.constant([[5,6],
                 [7,8]])

print(tf.matmul(c,d))
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %% [markdown]
# # Practice

# %%
scalar = tf.constant(10)

print(scalar)
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
print(scalar.shape)
print(scalar.dtype)
print(type(scalar))
print(scalar.ndim)
# Out:
# ()
# <dtype: 'int32'>
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 0

# %%
vector = tf.constant([1,2,3,4])

print(vector)
# Out:
# tf.Tensor([1 2 3 4], shape=(4,), dtype=int32)

# %%
print(vector.shape)
print(vector.dtype)
print(type(vector))
print(vector.ndim)
# Out:
# (4,)
# <dtype: 'int32'>
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 1

# %%
matrix = tf.constant([
    [1,2],
    [3,4]])

print(matrix)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
print(matrix.shape)
print(matrix.dtype)
print(type(matrix))
print(matrix.ndim)
# Out:
# (2, 2)
# <dtype: 'int32'>
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 2

# %%
a  = tf.constant([1,2,3,4,5])

b = tf.constant([6,7,8,9,0])

print(a+b)
print(a*b)
# Out:
# tf.Tensor([ 7  9 11 13  5], shape=(5,), dtype=int32)
# tf.Tensor([ 6 14 24 36  0], shape=(5,), dtype=int32)

# %%
c = tf.constant([
    [1,2],
    [3,4]])
d = tf.constant([
    [5,6],
    [7,8]])

print(c+d)
print(c*d)
# Out:
# tf.Tensor(
# [[ 6  8]
#  [10 12]], shape=(2, 2), dtype=int32)
# tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)

# %%
tensor_3d = tf.constant([
    [[1,2],
    [3,4]],

    [[5,6],
    [7,8]]])

print(tensor_3d)
# Out:
# tf.Tensor(
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]], shape=(2, 2, 2), dtype=int32)

# %%
print(tensor_3d.shape)
print(type(tensor_3d))
print(tensor_3d.dtype)
print(tensor_3d.ndim)
# Out:
# (2, 2, 2)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# <dtype: 'int32'>
# 3
