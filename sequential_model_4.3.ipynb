# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

# %%
print("X Train Shape: ",x_train.shape)
print("X Test Shape: ",x_test.shape)
# Out:
# X Train Shape:  (60000, 28, 28, 1)
# X Test Shape:  (10000, 28, 28, 1)

# %%
model = keras.Sequential([

    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu',
        strides=(2,2)
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),


    keras.layers.Conv2D(
        64,
        (3,3),
        activation='relu',
        strides=(2,2)
    ),
    keras.layers.MaxPooling2D(
        (2,2)
    ),


    keras.layers.Flatten(),

    keras.layers.Dense(
        64,
        activation = 'relu'
    ),
    keras.layers.Dense(
        10,
        activation = 'softmax'
    )
    
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8897 - loss: 0.3631 - val_accuracy: 0.9595 - val_loss: 0.1338
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9586 - loss: 0.1362 - val_accuracy: 0.9690 - val_loss: 0.1050
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9666 - loss: 0.1080 - val_accuracy: 0.9630 - val_loss: 0.1292
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9717 - loss: 0.0903 - val_accuracy: 0.9742 - val_loss: 0.0870
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9752 - loss: 0.0777 - val_accuracy: 0.9733 - val_loss: 0.0962
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9777 - loss: 0.0687 - val_accuracy: 0.9773 - val_loss: 0.0783
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9817 - loss: 0.0588 - val_accuracy: 0.9773 - val_loss: 0.0765
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9834 - loss: 0.0512 - val_accuracy: 0.9785 - val_loss: 0.0756
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9844 - loss: 0.0473 - val_accuracy: 0.9798 - val_loss: 0.0775
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9863 - loss: 0.0418 - val_accuracy: 0.9827 - val_loss: 0.0706
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9870 - loss: 0.0392 - val_accuracy: 0.9792 - val_loss: 0.0834
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9892 - loss: 0.0331 - val_accuracy: 0.9793 - val_loss: 0.0772
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9901 - loss: 0.0295 - val_accuracy: 0.9788 - val_loss: 0.0813
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9911 - loss: 0.0267 - val_accuracy: 0.9798 - val_loss: 0.0852
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9920 - loss: 0.0236 - val_accuracy: 0.9815 - val_loss: 0.0778
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9920 - loss: 0.0231 - val_accuracy: 0.9765 - val_loss: 0.0990
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9925 - loss: 0.0210 - val_accuracy: 0.9808 - val_loss: 0.0866
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9930 - loss: 0.0203 - val_accuracy: 0.9812 - val_loss: 0.0854
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9950 - loss: 0.0163 - val_accuracy: 0.9833 - val_loss: 0.0856
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9943 - loss: 0.0168 - val_accuracy: 0.9785 - val_loss: 0.1093

# %%
test_loss, test_accuracy = model.evaluate (x_test,y_test)
print("Test Accuracy: ",test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9753 - loss: 0.1094
# Test Accuracy:  0.9753000140190125

# %%
predictions = model.predict(x_train)

print("Predictions",predictions[:5])
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Predictions [[3.20081650e-09 1.47215783e-14 1.09203486e-13 3.15218978e-02
#   6.24909352e-18 9.68474090e-01 2.84802626e-10 1.65683569e-12
#   4.08576898e-06 9.73320269e-09]
#  [9.99997973e-01 4.78136385e-11 3.22257672e-11 1.28298186e-12
#   2.60978088e-12 3.65387805e-16 1.36058301e-14 1.27208633e-10
#   1.01968798e-08 2.06266873e-06]
#  [1.44597656e-09 4.37940101e-10 1.09168958e-07 4.42714848e-13
#   9.99999762e-01 6.97630981e-11 3.06361936e-10 2.17224994e-09
#   2.03378683e-08 5.87801310e-08]
#  [8.20466610e-08 9.99999285e-01 3.91068600e-09 2.73343305e-13
#   1.59745062e-09 3.44287626e-10 2.93935841e-07 3.47340978e-09
#   2.98877438e-07 1.06653797e-08]
#  [1.61641729e-17 3.91568126e-13 1.24690216e-13 3.61231417e-13
#   1.98906722e-08 5.25344351e-12 2.35611718e-20 2.84350772e-11
#   4.27506786e-09 1.00000000e+00]]

# %%
predicted_labels = np.argmax(predictions, axis=1)

print("Predicted: ",predicted_labels[:5])
print("Actual: ",y_test[:5])
# Out:
# Predicted:  [5 0 4 1 9]
# Actual:  [7 2 1 0 4]

# %%
print("Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Training Accuracy: ", max(history.history["accuracy"]))
print("Testing Accuracy: ",test_accuracy)
# Out:
# Validation Accuracy:  0.9833333492279053
# Training Accuracy:  0.9949629902839661
# Testing Accuracy:  0.9753000140190125

# %%
print("Best Validation Accuracy: ", max(history.history["val_accuracy"]))
print("Best Validation Loss: ", max(history.history["val_loss"]))
# Out:
# Best Validation Accuracy:  0.9833333492279053
# Best Validation Loss:  0.1338137537240982

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 13, 13, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 2, 2, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 70,880 (276.88 KB)
#  Trainable params: 23,626 (92.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 47,254 (184.59 KB)
